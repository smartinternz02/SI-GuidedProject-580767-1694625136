# %% [markdown]
# <a href="https://colab.research.google.com/github/smartinternz02/SI-GuidedProject-580767-1694625136/blob/main/sb_assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('Titanic-Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)
df["Cabin"].fillna(df["Cabin"].mode()[0],inplace=True)
df["Embarked"].fillna(df["Embarked"].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-1297-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-1298-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(df.Age)
# Out:
# <Axes: >

# %%
q1=df.Age.quantile(0.40)
q2=df.Age.quantile(0.60)

# %%
iqr=q2-q1
iqr
# Out:
# 1.69911764705882

# %%
upperlimit=q2+1.5*iqr
lowerlimit=q1-1.5*iqr

# %%
df.median()
# Out:
# <ipython-input-1304-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# PassengerId    446.000000
# Survived         0.000000
# Pclass           3.000000
# Age             29.699118
# SibSp            0.000000
# Parch            0.000000
# Fare            14.454200
# dtype: float64

# %%
df['Age']=np.where(df['Age']>upperlimit,29.699118,df['Age'])
df['Age']=np.where(df['Age']<lowerlimit,10,df['Age'])

# %%
sns.boxplot(df.Age)
# Out:
# <Axes: >

# %%
sns.boxplot(df.SibSp)
# Out:
# <Axes: >

# %%
p99=df.SibSp.quantile(0.965)

# %%
p99
# Out:
# 3.0

# %%
df=df[df.SibSp<p99]

# %%
sns.boxplot(df.SibSp)
# Out:
# <Axes: >

# %%
sns.boxplot(df.Parch)
# Out:
# <Axes: >

# %%
p99=df.Parch.quantile(0.90)
df=df[df.Parch<p99]
p99
# Out:
# 1.0

# %%
sns.boxplot(df.Parch)
# Out:
# <Axes: >

# %%
sns.boxplot(df.Fare)
# Out:
# <Axes: >

# %%
df.median()
# Out:
# <ipython-input-1316-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# PassengerId    452.500000
# Survived         0.000000
# Pclass           3.000000
# Age             29.699118
# SibSp            0.000000
# Parch            0.000000
# Fare            10.500000
# dtype: float64

# %%
q1 = df.Fare.quantile(0.25)
q2 = df.Fare.quantile(0.75)
iqr=q2-q1
upperlimit=q2+1.5*iqr
lowerlimit=q1-1.5*iqr
df['Fare']=np.where(df['Fare']>upperlimit,29.699118,df['Fare'])

# %%
sns.boxplot(df.Fare)
# Out:
# <Axes: >

# %%
x=df.iloc[:,0:11]
y=df.iloc[:,11:12]
print(x)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  10.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  29.699118
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  29.699118
# 4                             Allen, Mr. William Henry    male  29.699118
# ..                                                 ...     ...        ...
# ...

# %%
print(y)
# Out:
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 884        S
# 886        S
# 887        S
# 889        C
# 890        Q
#
# [676 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x["Name"]=le.fit_transform(x["Name"])
x["Sex"]=le.fit_transform(x["Sex"])
x["Ticket"]=le.fit_transform(x["Ticket"])
x["Cabin"]=le.fit_transform(x["Cabin"])
y["Embared"]=le.fit_transform(y["Embarked"])

# %%
x["Name"].nunique()
# Out:
# 676

# %%
x.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Sex        Age  SibSp  Parch  Ticket  \
# 0            1         0       3    71    1  10.000000      1      0     457
# 1            2         1       1   133    0  29.699118      1      0     516
# 2            3         1       3   255    0  26.000000      0      0     583
# 3            4         1       1   194    0  29.699118      1      0      43
# 4            5         0       3    12    1  29.699118      0      0     411
#
#         Fare  Cabin
# 0   7.250000     37
# 1  29.699118     63
# 2   7.925000     37
# 3  53.100000     44
# 4   8.050000     37

# %%
y.head()
# Out:
#   Embarked  Embared
# 0        S        2
# 1        C        0
# 2        S        2
# 3        S        2
# 4        S        2

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (540, 11) (136, 11) (540, 2) (136, 2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.65117461,  1.39671746, -1.57757038, ..., -1.19811865,
#          1.22872149, -0.25741612],
#        [-1.70703845,  1.39671746, -1.57757038, ..., -1.45467284,
#          1.74601918, -1.7361896 ],
#        [ 1.12837117,  1.39671746, -1.57757038, ..., -1.24942948,
#          1.25555286,  2.40437614],
#        ...,
#        [-0.37040184, -0.71596441, -0.38109846, ...,  1.46434377,
#          1.05230361, -0.25741612],
#        [ 0.46400741,  1.39671746, -1.57757038, ...,  1.20208837,
#          0.93340566,  3.17333835],
#        [-1.27994746, -0.71596441,  0.81537345, ...,  1.498551  ,
#         -0.79102934, -0.25741612]])

# %%
x_test
# Out:
# array([[ 1.66402532, -0.73854895, -0.39360273, ...,  1.32032833,
#         -0.53143274, -0.27591304],
#        [-0.01328401,  1.3540064 ,  0.7959522 , ...,  1.56949833,
#         -0.7554797 , -0.27591304],
#        [ 0.32141717, -0.73854895,  0.7959522 , ...,  0.83937228,
#         -0.74460363, -0.27591304],
#        ...,
#        [ 1.18099066, -0.73854895, -0.39360273, ..., -0.933791  ,
#         -0.31391141, -0.27591304],
#        [ 0.61047728, -0.73854895,  0.7959522 , ...,  1.46519461,
#         -0.74460363, -0.27591304],
#        [-0.27572017, -0.73854895, -1.58315766, ..., -1.66971171,
#          1.03472078,  0.19683245]])

# %%
y_train
# Out:
#     Embarked  Embared
# 290        S        2
# 23         S        2
# 740        S        2
# 536        S        2
# 866        C        0
# ..       ...      ...
# 92         S        2
# 135        C        0
# 361        C        0
# 572        S        2
# 131        S        2
#
# [540 rows x 2 columns]

# %%
y_test
# Out:
#     Embarked  Embared
# 841        S        2
# 400        S        2
# 488        S        2
# 648        S        2
# 759        S        2
# ..       ...      ...
# 66         S        2
# 274        Q        1
# 714        S        2
# 564        S        2
# 331        S        2
#
# [136 rows x 2 columns]
